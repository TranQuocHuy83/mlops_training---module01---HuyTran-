# %% [markdown]
# <a href="https://colab.research.google.com/github/TranQuocHuy83/mlops_training---module01---HuyTran-/blob/main/02_tensor_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Exercise 2: Tensor Operations
PyTorch Fundamentals - Module 1

This exercise covers:
- Basic arithmetic operations
- Matrix operations
- Reduction operations
- Comparison operations

PyTorch 2.0 Note: All operations in this file are compatible with PyTorch 2.0.
The @ operator for matrix multiplication is recommended for both PyTorch 1.x and 2.0.
"""

import torch

# %% [markdown]
# # ============================================
# # Part 1: Basic Arithmetic Operations
# # ============================================

# %%
# Set random seed for reproducibility
torch.manual_seed(42)

print("=" * 60)
print("Part 1: Basic Arithmetic Operations")
print("=" * 60)
# Out:
# ============================================================
# Part 1: Basic Arithmetic Operations
# ============================================================

# %%
# Create test tensors
x = torch.tensor([1, 2, 3, 4], dtype=torch.float32)
y = torch.tensor([5, 6, 7, 8], dtype=torch.float32)

print(f"x: {x}")
print(f"y: {y}")
# Out:
# x: tensor([1., 2., 3., 4.])
# y: tensor([5., 6., 7., 8.])

# %%
# TODO: Addition
add_result = x + y
print(f"\nAddition (x + y): {add_result}")
# Out:
# Addition (x + y): tensor([ 6.,  8., 10., 12.])

# %%
# TODO: Subtraction
sub_result = x - y
print(f"Subtraction (x - y): {sub_result}")
# Out:
# Subtraction (x - y): tensor([-4., -4., -4., -4.])

# %%
# TODO: Element-wise multiplication
mul_result = x * y
print(f"Multiplication (x * y): {mul_result}")
# Out:
# Multiplication (x * y): tensor([ 5., 12., 21., 32.])

# %%
# TODO: Element-wise division
div_result = x / y
print(f"Division (x / y): {div_result}")
# Out:
# Division (x / y): tensor([0.2000, 0.3333, 0.4286, 0.5000])

# %%
# TODO: Power
pow_result = x ** 2
print(f"Power (x^2): {pow_result}")
# Out:
# Power (x^2): tensor([ 1.,  4.,  9., 16.])

# %% [markdown]
# # ============================================
# # Part 2: Matrix Operations
# # ============================================

# %%
print("\n" + "=" * 60)
print("Part 2: Matrix Operations")
print("=" * 60)

# Create matrices
A = torch.randn(3, 4)
B = torch.randn(4, 5)

print(f"Matrix A shape: {A.shape}")
print(f"Matrix B shape: {B.shape}")
# Out:
# ============================================================
# Part 2: Matrix Operations
# ============================================================
# Matrix A shape: torch.Size([3, 4])
# Matrix B shape: torch.Size([4, 5])

# %%
# TODO: Matrix multiplication
matmul_result = A @ B
print(f"\nMatrix multiplication A @ B shape: {matmul_result.shape}\n")

# TODO: Transpose
A_T = A.T
print(A)
print(f"Matrix A shape: {A.shape}\n")
print(A_T)
print(f"Transpose of A shape: {A_T.shape}")
# Out:
# Matrix multiplication A @ B shape: torch.Size([3, 5])
#
# tensor([[ 0.3183,  1.1330, -1.1635, -2.6641],
#         [ 1.0122, -0.6236,  0.5438, -2.3363],
#         [ 0.1034,  0.2514,  1.2446,  0.5263]])
# Matrix A shape: torch.Size([3, 4])
#
# tensor([[ 0.3183,  1.0122,  0.1034],
#         [ 1.1330, -0.6236,  0.2514],
#         [-1.1635,  0.5438,  1.2446],
#         [-2.6641, -2.3363,  0.5263]])
# Transpose of A shape: torch.Size([4, 3])

# %%
# TODO: Element-wise min/max
min_val = torch.min(A)
max_val = torch.max(A)
print(f"\nMin value in A: {min_val:.4f}")
print(f"Max value in A: {max_val:.4f}")
# Out:
# Min value in A: -2.6641
# Max value in A: 1.2446

# %% [markdown]
# # ============================================
# # Part 3: Reduction Operations
# # ============================================

# %%
print("\n" + "=" * 60)
print("Part 3: Reduction Operations")
print("=" * 60)

# Create a 2D tensor
tensor = torch.randn(3, 4)
print(f"Tensor:\n{tensor}")
# Out:
# ============================================================
# Part 3: Reduction Operations
# ============================================================
# Tensor:
# tensor([[ 0.3471, -0.1014, -0.7543,  1.9346],
#         [-1.2589, -0.3895,  0.5330, -0.2423],
#         [ 0.6654,  0.9383,  0.0445,  1.1535]])

# %%
# TODO: Sum all elements
sum_all = torch.sum(tensor)
print(f"\nSum of all elements: {sum_all:.4f}")
# Out:
# Sum of all elements: 2.8699

# %%
# TODO: Sum along rows (dim=0)
sum_rows = torch.sum(tensor, dim=0)
print(f"Sum along rows: {sum_rows}")
# Out:
# Sum along rows: tensor([-0.2465,  0.4474, -0.1767,  2.8457])

# %%
# TODO: Sum along columns (dim=1)
sum_cols = torch.sum(tensor, dim=1)
print(f"Sum along columns: {sum_cols}")
# Out:
# Sum along columns: tensor([ 1.4260, -1.3578,  2.8017])

# %%
# TODO: Mean
mean_all = torch.mean(tensor)
print(f"\nMean of all elements: {mean_all:.4f}")
# Out:
# Mean of all elements: 0.2392

# %%
# TODO: Standard deviation
std_all = torch.std(tensor)
print(f"Standard deviation: {std_all:.4f}")
# Out:
# Standard deviation: 0.8786

# %% [markdown]
# # ============================================
# # Part 4: Comparison Operations
# # ============================================

# %%
print("\n" + "=" * 60)
print("Part 4: Comparison Operations")
print("=" * 60)

x = torch.tensor([1, 2, 3, 4, 5])
y = torch.tensor([2, 2, 4, 4, 6])

print(f"x: {x}")
print(f"y: {y}")
# Out:
# ============================================================
# Part 4: Comparison Operations
# ============================================================
# x: tensor([1, 2, 3, 4, 5])
# y: tensor([2, 2, 4, 4, 6])

# %%
# TODO: Element-wise comparison
eq_result = x == y
print(f"\nEqual (x == y): {eq_result}")
# Out:
# Equal (x == y): tensor([False,  True, False,  True, False])

# %%
gt_result = x > y
print(f"Greater than (x > y): {gt_result}")
# Out:
# Greater than (x > y): tensor([False, False, False, False, False])

# %%
lt_result = x < y
print(f"Less than (x < y): {lt_result}")
# Out:
# Less than (x < y): tensor([ True, False,  True, False,  True])

# %%
# TODO: Clamp values
clamped = torch.clamp(x, min=2, max=4)
print(f"\nClamp x to [2, 4]: {clamped}")
# Out:
# Clamp x to [2, 4]: tensor([2, 2, 3, 4, 4])

# %% [markdown]
# # ============================================
# # Part 5: Broadcasting
# # ============================================

# %%
print("\n" + "=" * 60)
print("Part 5: Broadcasting")
print("=" * 60)

# Create tensors with different shapes
x = torch.randn(3, 1)
y = torch.randn(1, 4)

print(f"x shape: {x.shape}")
print(f"y shape: {y.shape}")
# TODO: Broadcast addition
result = x + y
print(f"\nBroadcast result shape: {result.shape}")
print(f"Result:\n{result}")
# Out:
# ============================================================
# Part 5: Broadcasting
# ============================================================
# x shape: torch.Size([3, 1])
# y shape: torch.Size([1, 4])
#
# Broadcast result shape: torch.Size([3, 4])
# Result:
# tensor([[-1.5839, -0.5238,  0.0322, -1.8677],
#         [ 0.1877,  1.2478,  1.8038, -0.0961],
#         [-1.4232, -0.3631,  0.1929, -1.7071]])

# %% [markdown]
# # ============================================
# # Exercises
# # ============================================

# %%
print("\n" + "=" * 60)
print("Exercises")
print("=" * 60)
# Out:
# ============================================================
# Exercises
# ============================================================

# %%
# Exercise 1: Given two matrices A (4x3) and B (3x5), compute C = A @ B
print("\nExercise 1: Matrix multiplication")
A = torch.randn(4, 3)
B = torch.randn(3, 5)
# Compute C = A @ B
C = A @ B
print(A)
print(B)
print(C)
# Out:
# Exercise 1: Matrix multiplication
# tensor([[ 1.0716, -0.2662,  1.0295],
#         [ 0.1327,  1.8114, -1.0315],
#         [ 1.1471, -0.3532, -0.3664],
#         [ 0.0060, -0.9082, -0.3319]])
# tensor([[-0.1818,  0.5765,  0.3052,  0.2078,  0.2062],
#         [-0.4174,  1.3074,  2.8570, -1.4772, -0.0496],
#         [ 1.1342, -0.5377, -0.3539,  0.9743,  0.4280]])
# tensor([[ 1.0840e+00, -2.8382e-01, -7.9788e-01,  1.6190e+00,  6.7486e-01],
#         [-1.9502e+00,  2.9994e+00,  5.5808e+00, -3.6534e+00, -5.0405e-01],
#         [-4.7680e-01,  3.9667e-01, -5.2927e-01,  4.0300e-01,  9.7252e-02],
#         [ 1.5378e-03, -1.0054e+00, -2.4755e+00,  1.0195e+00, -9.5754e-02]])

# %%
# Exercise 2: Normalize a tensor to have zero mean and unit variance
print("\nExercise 2: Normalize tensor")
tensor = torch.randn(100, 10)
# Normalize: (x - mean) / std
mean = torch.mean(tensor)
std = torch.std(tensor)
normalized = (tensor - mean) / std
print(normalized)
print(torch.mean(normalized))
print(torch.std(normalized))
# Out:
# Exercise 2: Normalize tensor
# tensor([[-2.4899e-01, -6.7953e-01,  4.2981e-01, -9.0606e-01,  6.1204e-02,
#           4.9512e-01, -5.0546e-01, -1.2329e+00,  1.7377e-01, -4.9242e-02],
#         [-9.1482e-01,  1.1157e+00, -1.6365e+00, -3.6074e-01, -8.6251e-01,
#           7.4070e-01, -5.1768e-01,  4.2195e-03, -6.7168e-01,  1.2507e+00],
#         [-7.7420e-01, -1.0951e+00, -8.6099e-01,  6.7635e-01, -3.7963e-01,
#           5.7221e-01, -7.5343e-01, -6.4708e-01, -1.5068e+00, -2.4812e-01],
#         [ 1.8975e+00,  4.2127e-01, -4.9383e-01, -3.3311e-01,  1.0888e-01,
#           5.8691e-01,  7.6395e-01,  1.9860e-01, -9.1116e-01,  1.8498e+00],
#         [-3.2810e-01,  1.8001e-01, -1.9193e+00, -5.4806e-01, -6.7248e-01,
#           2.1280e-01, -2.2294e-01,  1.1578e+00, -2.0511e-01,  1.5098e+00],
#         [ 9.7364e-02,  2.6300e-01,  6.6243e-01, -2.0266e+00,  9.3555e-02,
#          -6.2112e-01,  5.1289e-01, -1.3257e+00, -4.5154e-01, -7.0596e-01],
#         [-1.4550e+00,  1.9939e+00, -1.3878e-01,  3.5397e-02,  1.1511e+00,
#           1.6554e-01, -6.5100e-01, -2.4659e-01, -8.8471e-01, -2.3170e+00],
#         [-9.2757e-01,  5.7713e-01, -3.6458e-01, -9.2696e-01,  1.3740e+00,
#           1.5183e+00, -6.1901e-01,  3.6762e-02, -2.2244e-01, -1.2409e+00],
#         [ 3.0266e-03,  2.6072e-01,  3.6876e-01,  2.3644e+00, -2.4560e-01,
#          -7.5521e-01,  4.2809e-01,  8.6965e-01, -1.4702e+00,  6.0481e-01],
#         [ 1.5859e-01, -1.0603e+00, -1.0445e+00,  3.4862e-01,  2.4377e-01,
#          -2.5815e+00,  4.1568e-01,  5.1487e-01,  1.9518e-01, -3.7019e-02],
#         [ 2.2971e-02,  4.8187e-01, -2.0690e+00,  3.5723e-01, -3.9303e-01,
#           1.4944e+00,  3.0118e-02, -3.4089e-01, -2.1010e-01, -2.3638e+00],
#         [-1.2792e+00, -6.5738e-02,  1.4542e-01, -1.5822e+00, -2.8736e-02,
#           1.1543e+00, -8.3009e-01,  5.1759e-01,  1.5017e+00,  1.3696e-01],
#         [-3.4678e-01,  1.1135e-01, -9.0376e-01, -1.6798e-01,  1.6671e+00,
#           7.1920e-03, -2.9171e-01,  9.4930e-01,  1.3164e+00,  9.8683e-01],
#         [ 4.8787e-01, -1.9644e+00,  2.0479e-01,  7.0461e-01, -6.7183e-01,
#          -2.9936e-01, -1.0914e-01, -1.4735e+00,  8.6216e-01, -6.2585e-01],
#         [-1.8105e+00, -6.7756e-01, -1.2201e+00, -1.1886e+00,  9.1112e-01,
#           4.7975e-01,  5.4044e-01,  5.7456e-02, -5.0700e-01,  6.6097e-01],
#         [-3.4072e-01,  1.8307e+00,  3.2873e-01, -1.0644e+00,  2.7658e-02,
#           2.1151e+00,  1.9746e+00, -1.4793e-01,  1.7180e-01, -8.6965e-01],
#         [ 1.2806e+00, -1.1440e+00,  1.4142e+00,  1.4940e+00, -2.8852e-01,
#          -8.0994e-01, -8.7739e-01, -9.7176e-01, -5.2770e-01,  2.5401e+00],
#         [ 1.1175e+00,  1.2148e+00,  2.2374e+00, -4.5196e-01,  3.0898e-01,
#           1.0414e+00,  5.8329e-01, -1.3841e+00, -4.2050e-01,  2.9555e+00],
#         [-9.5767e-01, -6.3294e-01, -1.3154e+00, -8.0554e-01, -4.8684e-01,
#           1.3828e-02, -1.2408e-01,  4.3421e-01, -4.0300e-01, -1.1631e+00],
#         [-6.2525e-01,  2.3546e-01, -1.8826e+00,  5.0932e-01,  1.6042e+00,
#          -1.5922e-01, -5.4556e-01,  2.5008e-01,  2.3143e-01,  6.8316e-01],
#         [-7.0107e-01,  1.9719e+00,  9.0938e-01, -1.0085e+00, -1.1925e+00,
#           4.6708e-01, -4.5387e-01,  6.9443e-01, -6.0931e-01, -1.4774e+00],
#         [-7.6725e-01,  1.0332e+00,  5.5351e-01, -1.5105e-01, -1.6304e+00,
#          -6.7542e-01,  1.8805e+00, -7.8912e-01,  4.2188e-01, -2.4472e+00],
#         [-3.8973e-01, -7.7786e-01, -1.3204e+00, -6.8046e-01, -5.3467e-01,
#           1.0306e+00,  6.0288e-01, -1.6939e+00, -1.3559e+00,  1.0385e+00],
#         [ 1.4568e+00, -1.1058e+00, -1.0592e+00, -6.7882e-01,  9.5780e-01,
#          -8.2024e-01,  1.0067e+00,  5.6430e-02,  1.1336e-01,  4.5655e-01],
#         [-1.9285e+00,  5.6321e-01,  1.3009e+00, -1.8568e-01, -2.0568e-01,
#           1.1260e+00,  9.4413e-01,  2.7529e-01,  9.7556e-02,  9.5140e-02],
#         [-5.6769e-01, -1.7169e+00, -5.0617e-01, -1.0411e+00, -8.9475e-01,
#          -2.4667e-02,  9.7376e-01, -5.3231e-01,  2.4134e+00,  9.0225e-01],
#         [-6.2098e-01, -6.3363e-01, -2.5572e+00,  1.2344e+00, -1.1656e+00,
#          -1.4658e-01, -6.1195e-01,  1.0144e+00, -5.7832e-01, -5.9111e-01],
#         [ 7.4054e-02, -4.7075e-01,  3.0434e-01,  1.0702e+00,  1.8000e+00,
#           2.4716e-01,  1.0627e+00, -1.1263e-01,  1.0496e+00,  7.4419e-01],
#         [-1.2903e+00, -4.8915e-01,  3.7084e-01,  1.0254e+00, -1.4497e-01,
#           3.8642e-01, -4.0485e-01, -5.4975e-02, -8.7019e-01, -3.3833e-01],
#         [ 6.0769e-01,  1.5488e-01, -2.1229e+00,  3.5735e-01,  8.4355e-01,
#          -1.1486e-01, -4.1188e-01, -3.1014e-01, -1.5052e+00,  1.5345e+00],
#         [ 8.1160e-01,  1.1877e+00,  1.4078e+00, -3.7782e-01,  1.7408e-01,
#           3.5522e-01, -8.8875e-02,  8.3281e-01,  5.3612e-01,  9.3830e-02],
#         [ 4.5333e-01, -1.3370e+00, -1.2731e+00, -1.4717e+00,  1.1020e+00,
#          -7.4750e-01,  9.4318e-01, -1.6757e+00, -3.2126e-01, -1.5140e-01],
#         [ 1.3912e+00,  1.9498e-01, -2.7492e-01,  7.3290e-01,  2.3772e-01,
#          -3.5254e-01,  1.7794e+00, -4.4775e-01, -7.0350e-02,  5.1081e-02],
#         [-7.9884e-01, -3.5785e-01, -4.0571e-02,  8.9251e-01,  5.4788e-01,
#           9.5448e-01,  1.8950e+00, -4.4474e-01,  2.2897e+00, -3.5315e-01],
#         [ 9.9265e-02, -1.4099e-01,  2.4683e-01, -4.1283e-01, -4.4359e-01,
#           1.1185e+00,  1.3360e+00, -4.1775e-01,  5.9422e-01,  1.6021e+00],
#         [ 1.4033e+00, -4.7153e-01,  1.4585e+00,  1.2402e+00,  6.2046e-01,
#          -8.1475e-01, -2.1226e+00, -2.4920e-01,  2.6522e-01,  4.8827e-01],
#         [ 5.3739e-01,  1.3293e+00, -2.4583e-01, -5.3991e-01, -1.4180e+00,
#          -7.0333e-01, -8.1923e-01, -8.6360e-01,  1.8719e+00,  1.0299e+00],
#         [ 7.4203e-01,  1.7858e+00,  7.2794e-01, -9.3694e-01, -6.2894e-02,
#           4.1354e-01, -3.2657e-01,  1.0656e+00,  1.8141e+00,  1.7570e-01],
#         [ 6.5646e-01, -8.1448e-01, -7.3117e-01,  2.3080e-01, -9.8479e-01,
#           4.2588e-01,  7.4987e-01, -9.5242e-01, -2.8179e-01,  4.6708e-01],
#         [ 1.7680e+00, -1.9045e-01,  7.0494e-01,  2.3967e-01, -1.0697e+00,
#          -1.4797e+00,  7.7081e-01, -6.3675e-01, -3.1905e-01, -5.9920e-01],
#         [ 4.9083e-01, -8.3031e-01,  1.6514e+00, -1.1547e+00,  1.3895e-01,
#           1.0346e+00,  2.6604e-01, -1.1793e+00, -2.1666e-01, -5.3889e-01],
#         [ 1.2386e+00, -1.5818e+00, -8.8009e-01, -1.5110e+00,  5.0722e-01,
#           7.1648e-01, -1.1162e+00, -7.3844e-01, -6.9757e-01, -4.2669e-01],
#         [-1.4515e+00, -1.5065e+00, -3.8546e-01,  2.2114e-01,  5.5551e-04,
#          -7.1080e-01, -6.9872e-01,  7.2815e-01,  1.8097e-01,  5.2680e-01],
#         [-9.3082e-01,  2.0162e+00,  8.0323e-02,  7.6889e-02, -8.0120e-01,
#           1.3791e+00, -1.8272e+00,  1.7470e-02, -7.1539e-01,  1.6668e+00],
#         [ 7.4526e-01, -1.7261e-01, -1.1782e-01,  2.4759e-01, -1.0810e+00,
#           9.1843e-02, -5.0603e-01,  5.5287e-01,  2.2507e+00, -5.3657e-01],
#         [ 1.0041e+00, -4.0862e-01, -3.6571e-01,  8.4239e-01,  1.7221e+00,
#          -1.5202e-01,  1.1768e+00,  5.8651e-01,  1.4562e+00, -5.0017e-01],
#         [-2.1190e-01, -1.2428e+00, -2.7711e-02,  1.1076e+00, -1.9859e+00,
#           6.0815e-01,  1.1617e+00,  1.2258e-02, -5.7667e-01, -1.4292e+00],
#         [ 1.4376e+00,  1.0416e+00, -6.1833e-01,  1.7534e+00,  4.5464e-01,
#           1.1445e-01, -3.1067e-02, -6.3822e-01, -1.3351e+00,  1.2527e+00],
#         [ 8.4635e-01,  1.7960e+00,  2.1943e-01,  6.6200e-01,  4.0648e-01,
#          -1.2950e+00, -2.3731e+00, -1.2875e+00, -1.4125e+00, -1.2580e+00],
#         [-2.0813e-01,  1.7487e-01,  7.9395e-01,  2.4808e-01,  9.0125e-03,
#          -3.6230e-01, -1.2331e+00, -1.2482e+00,  6.1111e-01,  2.0878e-01],
#         [-1.1692e+00,  7.0807e-01,  8.9901e-01, -1.4285e+00, -1.8256e+00,
#          -2.0730e+00, -6.6909e-01, -7.5052e-01,  3.4951e-01,  9.9616e-01],
#         [-1.5218e+00,  3.5139e-01,  3.2136e-01, -2.7421e-01, -1.0482e+00,
#          -7.4230e-01,  5.4845e-01,  1.3230e+00, -1.3161e+00,  6.3289e-01],
#         [ 3.9673e-01,  9.5491e-01,  1.6373e+00, -2.7642e-01,  8.8085e-01,
#          -5.4345e-01, -1.4324e+00,  7.6692e-01,  1.4657e+00,  4.1188e-01],
#         [-2.3997e+00,  6.1152e-01,  8.4144e-01, -9.1375e-02,  1.9189e-01,
#           9.6170e-01, -7.8197e-01,  1.0839e+00, -1.7007e+00,  9.1367e-01],
#         [ 7.1577e-01,  1.4830e-01,  3.3822e-01,  5.7229e-01,  4.9630e-01,
#           9.5867e-01,  1.5416e+00,  1.5340e+00,  1.0900e+00, -8.5451e-01],
#         [-9.8743e-01,  1.7576e-01, -7.4905e-01, -3.4550e-01,  3.8569e-01,
#           2.0382e-01,  2.0432e-01,  4.4630e-01, -1.0632e-02,  3.5368e-01],
#         [ 6.7574e-01,  3.1322e-01, -6.7482e-01,  1.5433e-01,  1.3689e+00,
#          -3.0258e+00,  1.0632e+00,  2.5641e-01, -1.5446e+00, -1.1668e+00],
#         [ 2.9995e-01, -5.2115e-02,  1.4688e+00,  1.1142e+00, -5.7979e-01,
#           6.8308e-01, -4.8402e-01,  1.0855e-01,  7.9156e-01,  1.5443e+00],
#         [ 3.1135e-01, -1.9900e-01, -5.0211e-01,  1.1069e+00,  7.4331e-01,
#           7.6962e-01,  2.5404e-02, -1.7078e+00, -1.7478e+00, -2.5158e-01],
#         [ 3.9561e-01,  9.0771e-02,  7.1154e-01, -8.7550e-01,  8.5237e-01,
#          -1.6405e+00, -7.1963e-01,  7.9246e-01,  1.4707e+00, -7.3746e-01],
#         [ 7.9157e-01, -1.2308e+00,  2.3816e-01,  1.2368e+00,  1.1207e+00,
#          -7.6220e-01,  1.5484e-01, -1.4900e+00, -2.1844e-01,  1.4560e+00],
#         [-1.2138e+00, -7.8069e-01, -1.3826e+00, -1.2355e+00, -1.2099e+00,
#          -3.0160e-01,  1.9434e-01, -4.6089e-01, -6.4976e-01, -3.2911e-01],
#         [-3.2909e-01,  2.4013e+00,  1.2640e+00, -7.7991e-02,  8.6300e-01,
#          -6.0087e-01,  8.0815e-01, -6.8331e-01, -2.3058e-01,  1.9103e-01],
#         [ 1.9602e+00, -4.6439e-01,  1.7567e+00, -7.2197e-01, -4.4531e-01,
#          -1.1385e+00, -8.3698e-01,  2.2452e+00,  7.4638e-02,  1.0696e+00],
#         [-9.9206e-01,  1.2123e+00,  1.1566e+00, -3.6861e-01,  5.1186e-01,
#           9.4080e-01,  6.8046e-01, -4.9577e-01, -6.6125e-01, -1.9946e+00],
#         [-6.1942e-01, -9.4675e-01,  7.5657e-01, -2.4991e-01, -9.3744e-02,
#           6.2750e-01,  1.0198e+00,  1.2790e+00,  2.5167e-01, -1.3055e+00],
#         [ 7.5474e-02, -1.4727e+00, -1.3385e+00,  1.4612e+00, -5.5706e-01,
#           1.9929e+00, -8.3227e-01,  9.0425e-01,  1.2605e+00, -8.6431e-01],
#         [ 5.8382e-01,  2.8478e+00,  1.1527e-01, -1.6654e-01,  1.1613e+00,
#           1.7054e+00, -1.5829e+00, -5.6885e-01,  2.4556e+00, -5.7567e-02],
#         [ 2.9147e-01, -6.8712e-01,  3.2120e-01, -3.2927e-01, -7.4166e-01,
#           1.2392e+00, -8.8846e-01, -3.8983e-01,  6.4230e-01,  1.9363e+00],
#         [ 4.4837e-01,  2.8579e-01,  3.8522e-01,  9.9654e-01, -1.3753e+00,
#          -4.8227e-01,  2.0602e+00, -3.5117e-01,  8.6679e-01, -2.4024e+00],
#         [-1.2033e+00,  6.6290e-01,  4.9298e-01, -2.3744e-03,  7.9983e-01,
#          -6.3687e-01, -1.1987e+00, -1.9649e-01,  1.2375e+00, -1.4970e+00],
#         [-7.6888e-01,  6.5892e-01,  1.7642e+00, -6.9944e-01, -2.0898e+00,
#           3.3644e-01, -8.7877e-01,  7.5460e-01,  3.8206e-01, -5.7432e-01],
#         [ 8.7320e-01, -1.5749e+00, -1.3319e+00, -2.6931e-01,  9.4987e-01,
#           1.9380e+00,  4.7482e-01, -8.1536e-01, -9.5027e-01, -5.8080e-01],
#         [ 1.0987e+00, -5.5918e-01,  5.6617e-01, -1.2457e+00, -4.1137e-01,
#           9.4608e-01, -4.6489e-01, -9.8998e-01, -3.2830e+00,  7.4098e-01],
#         [-3.0442e-01, -1.8206e-01,  1.1279e+00,  1.1321e+00, -7.4053e-01,
#           1.2820e-01, -7.7993e-01, -3.5787e-01, -1.3920e+00,  1.2765e-01],
#         [ 7.9708e-01, -1.3324e+00, -6.8927e-01,  4.2805e-01,  5.6429e-01,
#           7.6332e-01, -2.8137e-01, -8.2658e-01,  9.6611e-01, -7.8989e-03],
#         [ 4.8864e-01, -1.7317e+00, -8.0454e-01, -8.6805e-01,  3.5668e-01,
#          -2.2213e-01,  6.8549e-01, -1.9607e-01,  9.8790e-01,  2.1171e+00],
#         [-8.9767e-01,  2.0108e+00, -8.5109e-01,  3.8690e-02,  1.0257e+00,
#          -3.4424e-01,  7.9179e-01,  3.6925e-01, -5.2421e-01,  1.7336e+00],
#         [ 1.3576e+00, -2.2325e+00, -3.2445e-01,  3.0991e-01,  7.5924e-01,
#          -1.9771e-01,  4.9967e-01, -5.0064e-01, -7.7786e-01,  1.9986e-01],
#         [ 9.3446e-01, -4.5712e-01, -1.7242e+00,  1.0460e+00,  8.1334e-01,
#          -9.4461e-01,  1.3045e-01,  1.3439e+00,  6.0196e-01,  5.8487e-01],
#         [-3.8570e-01,  1.5101e+00, -5.9491e-02,  1.2940e+00, -1.3281e+00,
#           9.7410e-01,  2.7219e-01, -5.8699e-01, -3.3231e-01,  6.4586e-01],
#         [ 1.0210e+00, -9.8723e-01,  8.9726e-01, -7.0724e-01, -9.9190e-01,
#           4.2569e-01,  3.8842e-01,  1.9859e+00, -1.2140e+00,  2.5774e+00],
#         [-3.1250e-01, -1.2798e+00,  3.4068e-01, -1.0175e+00,  1.4810e-01,
#           5.6300e-01, -2.0913e-01, -1.3321e-01, -9.0283e-02,  3.6000e-01],
#         [-9.5629e-02, -3.1362e-01, -2.9986e-01, -1.6524e+00,  1.4937e+00,
#           1.7655e+00,  2.8012e-01,  5.8848e-01, -8.6003e-01, -1.1929e+00],
#         [ 6.0578e-01,  7.0832e-01, -1.1859e+00,  1.3643e+00, -2.0457e+00,
#           2.4143e+00, -3.2495e-02,  4.4320e-01,  5.7468e-01, -8.0187e-01],
#         [-2.1207e-01, -2.3470e+00, -8.6693e-01, -1.1459e+00, -7.0432e-01,
#          -3.0129e-01, -5.2006e-01,  9.0642e-01,  6.8512e-01, -5.7689e-01],
#         [ 9.1948e-03, -1.4006e+00,  6.3727e-01,  3.4375e-01, -8.1665e-01,
#          -1.0097e+00, -1.3676e+00, -4.1503e-01,  6.6351e-01,  9.4756e-01],
#         [ 7.2539e-01, -7.3279e-01,  1.4487e+00,  1.1943e+00, -1.8951e+00,
#          -1.1857e+00, -6.5343e-01,  6.3709e-02, -6.5102e-01,  5.0641e-01],
#         [ 1.9017e-03,  1.0293e-01,  2.2919e-01, -4.0731e-01, -1.2535e+00,
#          -7.8843e-01,  1.8099e+00,  1.6608e-01, -1.6341e-01, -1.8287e+00],
#         [-6.4816e-01,  6.5395e-01, -7.4776e-01, -1.0397e+00, -3.4959e-01,
#           5.0526e-01,  8.2382e-02,  2.8483e-01,  1.6961e-01, -4.0853e-01],
#         [ 9.7200e-01, -5.6308e-01, -5.1687e-01, -9.3562e-03, -2.7943e-01,
#          -1.2144e-03,  1.2202e+00, -3.1381e-01,  3.3107e-02, -5.5116e-01],
#         [ 1.1770e+00,  5.2572e-01,  1.8976e+00,  4.9824e-01, -8.6953e-01,
#          -2.7079e-01,  1.0678e-01, -5.1356e-01,  2.6820e+00,  4.4833e-01],
#         [ 1.7871e-02,  6.9593e-01, -1.0586e+00, -8.0828e-01, -1.5898e+00,
#          -2.3827e+00, -2.4909e-01,  4.2455e-01,  4.4368e-01,  8.6385e-01],
#         [-1.4725e+00, -1.2782e-01, -4.8198e-01,  1.1293e+00, -1.7765e+00,
#          -2.3565e+00, -5.6762e-02, -1.2937e-01,  1.3951e+00,  4.5064e-01],
#         [-1.9383e+00, -5.8999e-01, -1.5582e-01,  2.1330e+00,  3.3561e-01,
#           7.6416e-01, -1.5298e+00, -7.1965e-02, -3.7100e-01, -9.7356e-01],
#         [-6.0041e-01, -1.7646e-01,  9.2809e-01,  3.2363e-01, -5.1248e-01,
#           2.8737e-02,  2.1617e+00,  5.4838e-01,  2.5135e-01, -8.5683e-01],
#         [-4.5067e-01,  7.6156e-01,  7.8706e-01, -4.1687e-01,  2.0852e+00,
#           2.3565e-01, -1.1464e+00,  1.3803e+00, -5.4890e-02, -8.2447e-01],
#         [ 7.7452e-01,  1.2551e-01,  1.2719e+00,  6.9521e-01, -1.7470e+00,
#          -1.4595e+00, -5.7790e-01, -2.2996e-01,  3.2665e-01,  7.0979e-01],
#         [ 2.0415e-01, -4.7247e-01, -9.2800e-01,  1.2121e+00, -2.0992e+00,
#          -1.3005e+00, -3.5067e-01,  6.9767e-01, -8.2422e-01,  8.6704e-01],
#         [ 3.2629e-01,  1.5306e+00, -6.4740e-01,  1.2912e+00,  2.0016e+00,
#           2.3887e-01, -2.0286e-01, -3.7149e-01, -6.5591e-01, -1.1992e+00]])
# tensor(3.8147e-09)
# tensor(1.)

# %%
# Exercise 3: Find the indices of the top 3 values in a tensor
print("\nExercise 3: Find top 3 indices")
tensor = torch.randn(10)
# Find indices of top 3 values
top_3_indices = torch.topk(tensor, 3).indices
print(tensor)
print(top_3_indices)
# Out:
# Exercise 3: Find top 3 indices
# tensor([-0.6613,  2.0240,  0.3266,  0.4447,  0.7277,  1.1330, -0.1021,  0.9791,
#          0.1880,  0.3817])
# tensor([1, 5, 7])

# %%
# Exercise 4: Implement softmax function
print("\nExercise 4: Implement softmax")
logits = torch.randn(2, 5)  # Batch of 2, 5 classes
# Implement: softmax(x) = exp(x) / sum(exp(x))
softmax = torch.exp(logits) / torch.sum(torch.exp(logits))
print(softmax)
# Out:
# Exercise 4: Implement softmax
# tensor([[0.0534, 0.1410, 0.0274, 0.0447, 0.2010],
#         [0.1397, 0.1620, 0.0139, 0.0228, 0.1941]])

# %%
# Exercise 5: Compute cosine similarity between two vectors
print("\nExercise 5: Cosine similarity")
v1 = torch.randn(10)
v2 = torch.randn(10)
# Compute cosine similarity: (v1 . v2) / (||v1|| * ||v2||)
print(v1)
print(v2)
cosine_similarity = torch.dot(v1, v2) / (torch.norm(v1) * torch.norm(v2))
print(f"Cosin Similarity {cosine_similarity}")


print("\n" + "=" * 60)
print("Exercise 2 Complete!")
print("=" * 60)
# Out:
# Exercise 5: Cosine similarity
# tensor([-0.2460, -0.4367, -0.9273, -0.4265, -0.1204,  0.7827,  0.8690,  0.0953,
#         -0.3192, -1.0225])
# tensor([-0.1700, -0.1454, -0.4587,  0.4943,  0.7654,  0.8358, -0.0638,  0.4813,
#         -0.0033,  1.5297])
# Cosin Similarity -0.16888053715229034
#
# ============================================================
# Exercise 2 Complete!
# ============================================================
